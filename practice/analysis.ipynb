# %%
import pandas as pd
data = pd.read_csv('ConsumerExpenditures.csv')
data.head()
# Out:
#        Date     消費支出  消費支出増加フラグ  食料-1ヶ月前  住居-1ヶ月前  光熱・水道-1ヶ月前  家具・家事用品-1ヶ月前  \
# 0   1985年7月  281,604          1     81.1     75.6        87.9         155.5
# 1   1985年8月  266,596          0     81.8     75.7        87.8         155.5
# 2   1985年9月  249,416          0     81.8     75.8        87.8         155.3
# 3  1985年10月  264,096          1     81.3     75.9        87.8         155.7
# 4  1985年11月  257,024          0     82.9     76.0        87.8         155.8
#
#    被服及び履物-1ヶ月前  保健医療-1ヶ月前  交通・通信-1ヶ月前    ...     食料-6ヶ月前  住居-6ヶ月前  光熱・水道-6ヶ月前  \
# 0         82.0       80.3        99.1    ...        81.2     74.6        87.8
# 1         81.3       80.4        99.0    ...        80.9     74.7        87.6
# 2         78.2       80.4        98.8    ...        81.2     74.9        87.6
# 3         81.7       80.4        98.8    ...        81.5     75.1        87.8
# 4         82.7       80.5        99.2    ...        81.2     75.5        87.8
#
#    家具・家事用品-6ヶ月前  被服及び履物-6ヶ月前  保健医療-6ヶ月前  交通・通信-6ヶ月前  教育-6ヶ月前  教養娯楽-6ヶ月前  \
# 0         155.7         79.4       78.8        97.9     61.1      101.7
# 1         155.0         78.0       78.8        97.5     61.1      100.8
# 2         155.2         79.3       80.1        97.9     61.1      101.1
# 3         155.5         80.7       80.2        97.9     63.7      101.9
# 4         155.5         82.0       80.3        99.3     63.7      101.4
#
#    諸雑費-6ヶ月前
# 0      74.4
# 1      74.5
# 2      74.5
# 3      74.5
# 4      74.6
#
# [5 rows x 63 columns]

# %%
data.count()
# Out:
# Date            387
# 消費支出            387
# 消費支出増加フラグ       387
# 食料-1ヶ月前         387
# 住居-1ヶ月前         387
# 光熱・水道-1ヶ月前      387
# 家具・家事用品-1ヶ月前    387
# 被服及び履物-1ヶ月前     387
# 保健医療-1ヶ月前       387
# 交通・通信-1ヶ月前      387
# 教育-1ヶ月前         387
# 教養娯楽-1ヶ月前       387
# 諸雑費-1ヶ月前        387
# 食料-2ヶ月前         387
# 住居-2ヶ月前         387
# 光熱・水道-2ヶ月前      387
# 家具・家事用品-2ヶ月前    387
# 被服及び履物-2ヶ月前     387
# 保健医療-2ヶ月前       387
# 交通・通信-2ヶ月前      387
# 教育-2ヶ月前         387
# 教養娯楽-2ヶ月前       387
# 諸雑費-2ヶ月前        387
# 食料-3ヶ月前         387
# 住居-3ヶ月前         387
# 光熱・水道-3ヶ月前      387
# 家具・家事用品-3ヶ月前    387
# 被服及び履物-3ヶ月前     387
# 保健医療-3ヶ月前       387
# 交通・通信-3ヶ月前      387
#                ...
# 食料-4ヶ月前         387
# 住居-4ヶ月前         387
# 光熱・水道-4ヶ月前      387
# 家具・家事用品-4ヶ月前    387
# 被服及び履物-4ヶ月前     387
# 保健医療-4ヶ月前       387
# 交通・通信-4ヶ月前      387
# 教育-4ヶ月前         387
# 教養娯楽-4ヶ月前       387
# 諸雑費-4ヶ月前        387
# 食料-5ヶ月前         387
# 住居-5ヶ月前         387
# 光熱・水道-5ヶ月前      387
# 家具・家事用品-5ヶ月前    387
# 被服及び履物-5ヶ月前     387
# 保健医療-5ヶ月前       387
# 交通・通信-5ヶ月前      387
# 教育-5ヶ月前         387
# 教養娯楽-5ヶ月前       387
# 諸雑費-5ヶ月前        387
# 食料-6ヶ月前         387
# 住居-6ヶ月前         387
# 光熱・水道-6ヶ月前      387
# 家具・家事用品-6ヶ月前    387
# 被服及び履物-6ヶ月前     387
# 保健医療-6ヶ月前       387
# 交通・通信-6ヶ月前      387
# 教育-6ヶ月前         387
# 教養娯楽-6ヶ月前       387
# 諸雑費-6ヶ月前        387
# Length: 63, dtype: int64

# %%
data.columns
# Out:
# Index(['Date', '消費支出', '消費支出増加フラグ', '食料-1ヶ月前', '住居-1ヶ月前', '光熱・水道-1ヶ月前',
#        '家具・家事用品-1ヶ月前', '被服及び履物-1ヶ月前', '保健医療-1ヶ月前', '交通・通信-1ヶ月前', '教育-1ヶ月前',
#        '教養娯楽-1ヶ月前', '諸雑費-1ヶ月前', '食料-2ヶ月前', '住居-2ヶ月前', '光熱・水道-2ヶ月前',
#        '家具・家事用品-2ヶ月前', '被服及び履物-2ヶ月前', '保健医療-2ヶ月前', '交通・通信-2ヶ月前', '教育-2ヶ月前',
#        '教養娯楽-2ヶ月前', '諸雑費-2ヶ月前', '食料-3ヶ月前', '住居-3ヶ月前', '光熱・水道-3ヶ月前',
#        '家具・家事用品-3ヶ月前', '被服及び履物-3ヶ月前', '保健医療-3ヶ月前', '交通・通信-3ヶ月前', '教育-3ヶ月前',
#        '教養娯楽-3ヶ月前', '諸雑費-3ヶ月前', '食料-4ヶ月前', '住居-4ヶ月前', '光熱・水道-4ヶ月前',
#        '家具・家事用品-4ヶ月前', '被服及び履物-4ヶ月前', '保健医療-4ヶ月前', '交通・通信-4ヶ月前', '教育-4ヶ月前',
#        '教養娯楽-4ヶ月前', '諸雑費-4ヶ月前', '食料-5ヶ月前', '住居-5ヶ月前', '光熱・水道-5ヶ月前',
#        '家具・家事用品-5ヶ月前', '被服及び履物-5ヶ月前', '保健医療-5ヶ月前', '交通・通信-5ヶ月前', '教育-5ヶ月前',
#        '教養娯楽-5ヶ月前', '諸雑費-5ヶ月前', '食料-6ヶ月前', '住居-6ヶ月前', '光熱・水道-6ヶ月前',
#        '家具・家事用品-6ヶ月前', '被服及び履物-6ヶ月前', '保健医療-6ヶ月前', '交通・通信-6ヶ月前', '教育-6ヶ月前',
#        '教養娯楽-6ヶ月前', '諸雑費-6ヶ月前'],
#       dtype='object')

# %%
data_tmp = data.copy()
del data_tmp['Date']
del data_tmp['消費支出']
data_tmp_X = data_tmp.copy()
del data_tmp_X['消費支出増加フラグ']
data_tmp_Y = data_tmp['消費支出増加フラグ']
data_tmp_X.columns
# Out:
# Index(['食料-1ヶ月前', '住居-1ヶ月前', '光熱・水道-1ヶ月前', '家具・家事用品-1ヶ月前', '被服及び履物-1ヶ月前',
#        '保健医療-1ヶ月前', '交通・通信-1ヶ月前', '教育-1ヶ月前', '教養娯楽-1ヶ月前', '諸雑費-1ヶ月前',
#        '食料-2ヶ月前', '住居-2ヶ月前', '光熱・水道-2ヶ月前', '家具・家事用品-2ヶ月前', '被服及び履物-2ヶ月前',
#        '保健医療-2ヶ月前', '交通・通信-2ヶ月前', '教育-2ヶ月前', '教養娯楽-2ヶ月前', '諸雑費-2ヶ月前',
#        '食料-3ヶ月前', '住居-3ヶ月前', '光熱・水道-3ヶ月前', '家具・家事用品-3ヶ月前', '被服及び履物-3ヶ月前',
#        '保健医療-3ヶ月前', '交通・通信-3ヶ月前', '教育-3ヶ月前', '教養娯楽-3ヶ月前', '諸雑費-3ヶ月前',
#        '食料-4ヶ月前', '住居-4ヶ月前', '光熱・水道-4ヶ月前', '家具・家事用品-4ヶ月前', '被服及び履物-4ヶ月前',
#        '保健医療-4ヶ月前', '交通・通信-4ヶ月前', '教育-4ヶ月前', '教養娯楽-4ヶ月前', '諸雑費-4ヶ月前',
#        '食料-5ヶ月前', '住居-5ヶ月前', '光熱・水道-5ヶ月前', '家具・家事用品-5ヶ月前', '被服及び履物-5ヶ月前',
#        '保健医療-5ヶ月前', '交通・通信-5ヶ月前', '教育-5ヶ月前', '教養娯楽-5ヶ月前', '諸雑費-5ヶ月前',
#        '食料-6ヶ月前', '住居-6ヶ月前', '光熱・水道-6ヶ月前', '家具・家事用品-6ヶ月前', '被服及び履物-6ヶ月前',
#        '保健医療-6ヶ月前', '交通・通信-6ヶ月前', '教育-6ヶ月前', '教養娯楽-6ヶ月前', '諸雑費-6ヶ月前'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(data_tmp_X, data_tmp_Y,random_state=0, test_size=0.3)
print(len(X_train))
print(len(Y_train))
print(len(X_test))
print(len(Y_test))
# Out:
# 270
# 270
# 117
# 117

# %%
from sklearn.tree import DecisionTreeClassifier
treeModel = DecisionTreeClassifier(max_depth=3, random_state=0)
treeModel.fit(X_train, Y_train)
from sklearn import metrics
print(metrics.accuracy_score(Y_train, treeModel.predict(X_train)))
print(metrics.accuracy_score(Y_test, treeModel.predict(X_test)))
# Out:
# 0.7851851851851852
# 0.6068376068376068

# %%
Importance = pd.DataFrame({'変数名':data_tmp_X.columns, '重要度':treeModel.feature_importances_})
Importance[Importance['重要度'] != 0]
# Out:
#              変数名       重要度
# 24   被服及び履物-3ヶ月前  0.152618
# 34   被服及び履物-4ヶ月前  0.413915
# 53  家具・家事用品-6ヶ月前  0.041135
# 54   被服及び履物-6ヶ月前  0.392332

# %%
treeModel = DecisionTreeClassifier(max_depth=2, random_state=0)
treeModel.fit(X_train, Y_train)
print(metrics.accuracy_score(Y_train, treeModel.predict(X_train)))
print(metrics.accuracy_score(Y_test, treeModel.predict(X_test)))
# Out:
# 0.7
# 0.6324786324786325

# %%
from sklearn.linear_model import LogisticRegression
logModel = LogisticRegression()
logModel.fit(X_train, Y_train)
print(metrics.accuracy_score(Y_test, logModel.predict(X_test)))
print(metrics.accuracy_score(Y_train, logModel.predict(X_train)))
# Out:
# 0.7948717948717948
# 0.8333333333333334

# %%
Coef = pd.DataFrame({'変数名':data_tmp_X.columns, '係数':logModel.coef_[0]})
Coef.sort_values('係数')
# Out:
#           係数           変数名
# 37 -2.273683       教育-4ヶ月前
# 47 -1.052119       教育-5ヶ月前
# 51 -0.999525       住居-6ヶ月前
# 58 -0.806695     教養娯楽-6ヶ月前
# 56 -0.738079    交通・通信-6ヶ月前
# 32 -0.464957    光熱・水道-4ヶ月前
# 20 -0.413826       食料-3ヶ月前
# 10 -0.413826       食料-2ヶ月前
# 36 -0.388649    交通・通信-4ヶ月前
# 8  -0.371724     教養娯楽-1ヶ月前
# 30 -0.360924       食料-4ヶ月前
# 1  -0.258609       住居-1ヶ月前
# 41 -0.206650       住居-5ヶ月前
# 45 -0.205143     保健医療-5ヶ月前
# 35 -0.157766     保健医療-4ヶ月前
# 18 -0.155990     教養娯楽-2ヶ月前
# 28 -0.155990     教養娯楽-3ヶ月前
# 34 -0.136618   被服及び履物-4ヶ月前
# 13 -0.136376  家具・家事用品-2ヶ月前
# 23 -0.136376  家具・家事用品-3ヶ月前
# 6  -0.135891    交通・通信-1ヶ月前
# 7  -0.101942       教育-1ヶ月前
# 4  -0.084671   被服及び履物-1ヶ月前
# 59 -0.077482      諸雑費-6ヶ月前
# 33 -0.056674  家具・家事用品-4ヶ月前
# 9  -0.053641      諸雑費-1ヶ月前
# 44 -0.051811   被服及び履物-5ヶ月前
# 43 -0.050245  家具・家事用品-5ヶ月前
# 25 -0.041675     保健医療-3ヶ月前
# 15 -0.041675     保健医療-2ヶ月前
# 52 -0.020297    光熱・水道-6ヶ月前
# 29  0.014231      諸雑費-3ヶ月前
# 19  0.014231      諸雑費-2ヶ月前
# 2   0.032779    光熱・水道-1ヶ月前
# 48  0.035092     教養娯楽-5ヶ月前
# 3   0.047805  家具・家事用品-1ヶ月前
# 5   0.118717     保健医療-1ヶ月前
# 12  0.135420    光熱・水道-2ヶ月前
# 22  0.135420    光熱・水道-3ヶ月前
# 0   0.160289       食料-1ヶ月前
# 39  0.162626      諸雑費-4ヶ月前
# 14  0.181376   被服及び履物-2ヶ月前
# 24  0.181376   被服及び履物-3ヶ月前
# 49  0.200256      諸雑費-5ヶ月前
# 46  0.247357    交通・通信-5ヶ月前
# 42  0.263028    光熱・水道-5ヶ月前
# 55  0.266710     保健医療-6ヶ月前
# 31  0.285913       住居-4ヶ月前
# 54  0.297080   被服及び履物-6ヶ月前
# 26  0.338698    交通・通信-3ヶ月前
# 16  0.338698    交通・通信-2ヶ月前
# 50  0.344090       食料-6ヶ月前
# 40  0.375601       食料-5ヶ月前
# 53  0.527681  家具・家事用品-6ヶ月前
# 11  0.632748       住居-2ヶ月前
# 21  0.632748       住居-3ヶ月前
# 38  1.093756     教養娯楽-4ヶ月前
# 17  1.119057       教育-2ヶ月前
# 27  1.119057       教育-3ヶ月前
# 57  1.247392       教育-6ヶ月前
